# %% [markdown]
# <a href="https://colab.research.google.com/github/gm-0liveira/Estudos-Pandas/blob/main/desbravando_pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Séries

# %% [markdown]
# - Diferente das listas, todos os elementos das séries precisam ser de um mesmo
# tipo!

# %%
# Lista
idade = [31, 33, 2, 5, 78, 45, 89]

# Série
s_idade = pd.Series(idade)
s_idade
# Out:
# 0    31
# 1    33
# 2     2
# 3     5
# 4    78
# 5    45
# 6    89
# dtype: int64

# %%
# Utilizando métodos das Séries
media = s_idade.mean()
media
# Out:
# 40.42857142857143

# %%
variancia = s_idade.var()
variancia
# Out:
# 1111.285714285714

# %%
desvio_padrao = s_idade.std()
desvio_padrao
# Out:
# 33.33595227806931

# %%
# Faz uma breve descrição da série levando em conta dados de posição e dispersão
s_idade.describe()
# Out:
# count     7.000000
# mean     40.428571
# std      33.335952
# min       2.000000
# 25%      18.000000
# 50%      33.000000
# 75%      61.500000
# max      89.000000
# dtype: float64

# %% [markdown]
# - Imagine que seja necessário buscar as idades maiores do que 30 anos na lista
# de idades. Para esse problema é possivel utilizar um laço `for` como a seguir:

# %%
maior30 = []
for i in idade:
  if i >= 30:
    maior30.append(i)

maior30
# Out:
# [31, 33, 78, 45, 89]

# %% [markdown]
# - Apesar de resolver o problema, além de utilizar um loop `for` que atrapalha na
# performace de código também possui uma solução mais prática quando utilizada com as séries, como visto a seguir:

# %%
filtro = s_idade >= 30

s_idade[filtro]
# Out:
# 0    31
# 1    33
# 4    78
# 5    45
# 6    89
# dtype: int64

# %% [markdown]
# - Primeiro é comparado os valores da série com o escalar apresentado, neste caso 30, depois é retornado os valores booleanos para cada uma das comparações, quando associamos isso para os valores de cada uma destas comparações como visto em `s_idade[filtro]` temos o retorno dos valores sendo uma solução mais elegante ao problema

# %% [markdown]
# - O mesmo conceito pode ser utilizado para a coleta de elementos em um array, utilizando dos valores booleanos indicados:

# %%
s_idade[[True, False, True, True, False, False, True]]
# Out:
# 0    31
# 2     2
# 3     5
# 6    89
# dtype: int64

# %% [markdown]
# # Dataframes

# %%
# Criando um dicionário
data = {
    "nome": ["Gustavo", "Teo", "Maria", "Jessica", "Erick", "Felipe", "Lucas"],
    "idade": [24, 30, 2, 41, 23, 23, 24],
    "cor": ["Preto", "Verde", "Azul", "Amarelo", "Laranja", "Vermelho", "Branco"],
    "renda": [3560, 5476, 8520, 1236, 4521, 1212, 0]
}

# %%
# Criando um dataframe apartir do dicionário
df = pd.DataFrame(data)
df
# Out:
#       nome  idade       cor  renda
# 0  Gustavo     24     Preto   3560
# 1      Teo     30     Verde   5476
# 2    Maria      2      Azul   8520
# 3  Jessica     41   Amarelo   1236
# 4    Erick     23   Laranja   4521
# 5   Felipe     23  Vermelho   1212
# 6    Lucas     24    Branco      0

# %% [markdown]
# - Um dataframe é um agregador de séries, tornando-as relacionadas

# %%
# Acessando a série de idade do dataframe
df["idade"]
# Out:
# 0    24
# 1    30
# 2     2
# 3    41
# 4    23
# 5    23
# 6    24
# Name: idade, dtype: int64

# %%
type(df["idade"])
# Out:
# pandas.core.series.Series

# %%
# É possivel passar métodos para os dataframes que os aplica a cada série (coluna) de acordo com a correspondência do método
df.describe()
# Out:
#            idade        renda
# count   7.000000     7.000000
# mean   23.857143  3503.571429
# std    11.625096  2965.399572
# min     2.000000     0.000000
# 25%    23.000000  1224.000000
# 50%    24.000000  3560.000000
# 75%    27.000000  4998.500000
# max    41.000000  8520.000000

# %% [markdown]
# # Importação de Arquivos

# %%
df = pd.read_csv("/content/drive/MyDrive/Estudos/Desbravando Pandas/data/pedido.csv")
df
# Out:
#       idPedido                      dtPedido flKetchup             descUF  \
# 0            0  2023-05-11T10:59:33.000+0000       NaN              Goiás
# 1            1  2023-05-11T11:23:42.000+0000       NaN             Paraná
# 2            2  2023-05-11T11:24:29.000+0000       NaN          São Paulo
# 3            3  2023-05-11T11:29:39.000+0000       NaN          São Paulo
# 4            4  2023-05-11T11:31:30.000+0000       NaN  Rio Grande do Sul
# ...        ...                           ...       ...                ...
# 1101      1101  2023-05-25T16:47:40.000+0000      True            Sergipe
# 1102      1102  2023-05-25T16:55:35.000+0000     False          São Paulo
# 1103      1103  2023-05-25T17:07:05.000+0000     False          São Paulo
# 1104      1104  2023-05-25T18:18:02.000+0000      True          São Paulo
# 1105      1105  2023-05-25T18:27:12.000+0000     False          São Paulo
#
#                                               txtRecado
# 0                                                   NaN
# 1                            Aquela pizza perfeita! :-D
# 2                                      Muito obrigado!!
# 3                                                   NaN
# 4                                  Capricha no peperoni
# ...                                                 ...
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.
#
# [1106 rows x 5 columns]

# %% [markdown]
# ## Pegando os atributos de um dataframe

# %%
# Selecionando as colunas
df.columns
# Out:
# Index(['idPedido', 'dtPedido', 'flKetchup', 'descUF', 'txtRecado'], dtype='object')

# %%
# Selecionando o formato
df.shape
# Out:
# (1106, 5)

# %%
# Selecionando os indexes
df.index
# Out:
# RangeIndex(start=0, stop=1106, step=1)

# %%
# Selecionando informações úteis
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   idPedido   1106 non-null   int64
#  1   dtPedido   1106 non-null   object
#  2   flKetchup  1097 non-null   object
#  3   descUF     1106 non-null   object
#  4   txtRecado  538 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 295.4 KB

# %%
# Selecionando os tipos de cada coluna do dataframe
df.dtypes
# Out:
# idPedido      int64
# dtPedido     object
# flKetchup    object
# descUF       object
# txtRecado    object
# dtype: object

# %% [markdown]
# ## Utilizando métodos em um dataframe

# %%
# Cabeçalho do Dataframe
df.head()
# Out:
#    idPedido                      dtPedido flKetchup             descUF  \
# 0         0  2023-05-11T10:59:33.000+0000       NaN              Goiás
# 1         1  2023-05-11T11:23:42.000+0000       NaN             Paraná
# 2         2  2023-05-11T11:24:29.000+0000       NaN          São Paulo
# 3         3  2023-05-11T11:29:39.000+0000       NaN          São Paulo
# 4         4  2023-05-11T11:31:30.000+0000       NaN  Rio Grande do Sul
#
#                     txtRecado
# 0                         NaN
# 1  Aquela pizza perfeita! :-D
# 2            Muito obrigado!!
# 3                         NaN
# 4        Capricha no peperoni

# %%
# Final do Dataframe
df.tail()
# Out:
#       idPedido                      dtPedido flKetchup     descUF  \
# 1101      1101  2023-05-25T16:47:40.000+0000      True    Sergipe
# 1102      1102  2023-05-25T16:55:35.000+0000     False  São Paulo
# 1103      1103  2023-05-25T17:07:05.000+0000     False  São Paulo
# 1104      1104  2023-05-25T18:18:02.000+0000      True  São Paulo
# 1105      1105  2023-05-25T18:27:12.000+0000     False  São Paulo
#
#                                               txtRecado
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.

# %%
# Linhas aleatórias do Dataframe
df.sample(10)
# Out:
#      idPedido                      dtPedido flKetchup          descUF  \
# 663       663  2023-05-24T14:09:43.000+0000      True       São Paulo
# 359       359  2023-05-23T09:35:09.000+0000     False       São Paulo
# 859       859  2023-05-24T17:06:12.000+0000     False       São Paulo
# 265       265  2023-05-19T00:13:57.000+0000     False           Piauí
# 438       438  2023-05-23T14:42:04.000+0000     False       São Paulo
# 600       600  2023-05-24T13:46:35.000+0000     False       São Paulo
# 530       530  2023-05-24T13:29:03.000+0000     False      Pernambuco
# 18         18  2023-05-11T15:36:52.000+0000      True  Santa Catarina
# 104       104  2023-05-13T19:43:50.000+0000     False       São Paulo
# 144       144  2023-05-15T09:17:08.000+0000     False    Minas Gerais
#
#                     txtRecado
# 663                      Null
# 359               No capricho
# 859                       NaN
# 265  Nao economiza no cheddar
# 438                    Salve!
# 600                       NaN
# 530                       NaN
# 18                        NaN
# 104                       NaN
# 144                       NaN

# %% [markdown]
# # Navegando

# %%
df = pd.read_csv("/content/drive/MyDrive/Estudos/Desbravando Pandas/data/pedido.csv")
df
# Out:
#       idPedido                      dtPedido flKetchup             descUF  \
# 0            0  2023-05-11T10:59:33.000+0000       NaN              Goiás
# 1            1  2023-05-11T11:23:42.000+0000       NaN             Paraná
# 2            2  2023-05-11T11:24:29.000+0000       NaN          São Paulo
# 3            3  2023-05-11T11:29:39.000+0000       NaN          São Paulo
# 4            4  2023-05-11T11:31:30.000+0000       NaN  Rio Grande do Sul
# ...        ...                           ...       ...                ...
# 1101      1101  2023-05-25T16:47:40.000+0000      True            Sergipe
# 1102      1102  2023-05-25T16:55:35.000+0000     False          São Paulo
# 1103      1103  2023-05-25T17:07:05.000+0000     False          São Paulo
# 1104      1104  2023-05-25T18:18:02.000+0000      True          São Paulo
# 1105      1105  2023-05-25T18:27:12.000+0000     False          São Paulo
#
#                                               txtRecado
# 0                                                   NaN
# 1                            Aquela pizza perfeita! :-D
# 2                                      Muito obrigado!!
# 3                                                   NaN
# 4                                  Capricha no peperoni
# ...                                                 ...
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.
#
# [1106 rows x 5 columns]

# %% [markdown]
# ## Organizando as Colunas

# %%
# Selecionando apenas uma coluna
df['idPedido']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 1101    1101
# 1102    1102
# 1103    1103
# 1104    1104
# 1105    1105
# Name: idPedido, Length: 1106, dtype: int64

# %%
# Selecionando mais de uma coluna
df[["dtPedido", "idPedido"]]
# Out:
#                           dtPedido  idPedido
# 0     2023-05-11T10:59:33.000+0000         0
# 1     2023-05-11T11:23:42.000+0000         1
# 2     2023-05-11T11:24:29.000+0000         2
# 3     2023-05-11T11:29:39.000+0000         3
# 4     2023-05-11T11:31:30.000+0000         4
# ...                            ...       ...
# 1101  2023-05-25T16:47:40.000+0000      1101
# 1102  2023-05-25T16:55:35.000+0000      1102
# 1103  2023-05-25T17:07:05.000+0000      1103
# 1104  2023-05-25T18:18:02.000+0000      1104
# 1105  2023-05-25T18:27:12.000+0000      1105
#
# [1106 rows x 2 columns]

# %%
# Organizando a exibição das colunas de um dataframe
df[['idPedido', 'flKetchup', 'descUF', 'txtRecado', 'dtPedido']]
# Out:
#       idPedido flKetchup             descUF  \
# 0            0       NaN              Goiás
# 1            1       NaN             Paraná
# 2            2       NaN          São Paulo
# 3            3       NaN          São Paulo
# 4            4       NaN  Rio Grande do Sul
# ...        ...       ...                ...
# 1101      1101      True            Sergipe
# 1102      1102     False          São Paulo
# 1103      1103     False          São Paulo
# 1104      1104      True          São Paulo
# 1105      1105     False          São Paulo
#
#                                               txtRecado  \
# 0                                                   NaN
# 1                            Aquela pizza perfeita! :-D
# 2                                      Muito obrigado!!
# 3                                                   NaN
# 4                                  Capricha no peperoni
# ...                                                 ...
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.
#
#                           dtPedido
# 0     2023-05-11T10:59:33.000+0000
# 1     2023-05-11T11:23:42.000+0000
# 2     2023-05-11T11:24:29.000+0000
# 3     2023-05-11T11:29:39.000+0000
# 4     2023-05-11T11:31:30.000+0000
# ...                            ...
# 1101  2023-05-25T16:47:40.000+0000
# 1102  2023-05-25T16:55:35.000+0000
# 1103  2023-05-25T17:07:05.000+0000
# 1104  2023-05-25T18:18:02.000+0000
# 1105  2023-05-25T18:27:12.000+0000
#
# [1106 rows x 5 columns]

# %%
# Alterando a disposição das colunas de um dataframe
df = df[['idPedido', 'flKetchup', 'descUF', 'txtRecado', 'dtPedido']]
df
# Out:
#       idPedido flKetchup             descUF  \
# 0            0       NaN              Goiás
# 1            1       NaN             Paraná
# 2            2       NaN          São Paulo
# 3            3       NaN          São Paulo
# 4            4       NaN  Rio Grande do Sul
# ...        ...       ...                ...
# 1101      1101      True            Sergipe
# 1102      1102     False          São Paulo
# 1103      1103     False          São Paulo
# 1104      1104      True          São Paulo
# 1105      1105     False          São Paulo
#
#                                               txtRecado  \
# 0                                                   NaN
# 1                            Aquela pizza perfeita! :-D
# 2                                      Muito obrigado!!
# 3                                                   NaN
# 4                                  Capricha no peperoni
# ...                                                 ...
# 1101  Esse formulário deu fome no meio do expediente...
# 1102                                                NaN
# 1103                                    Bastante queijo
# 1104                                                NaN
# 1105      Favor deixar a massa crocante e lave as mãos.
#
#                           dtPedido
# 0     2023-05-11T10:59:33.000+0000
# 1     2023-05-11T11:23:42.000+0000
# 2     2023-05-11T11:24:29.000+0000
# 3     2023-05-11T11:29:39.000+0000
# 4     2023-05-11T11:31:30.000+0000
# ...                            ...
# 1101  2023-05-25T16:47:40.000+0000
# 1102  2023-05-25T16:55:35.000+0000
# 1103  2023-05-25T17:07:05.000+0000
# 1104  2023-05-25T18:18:02.000+0000
# 1105  2023-05-25T18:27:12.000+0000
#
# [1106 rows x 5 columns]

# %% [markdown]
# ## Organizando as Linhas

# %%
# Pegando 100 linhas aleatórias do dataframe
df_sample = df.sample(100)
df_sample
# Out:
#       idPedido flKetchup              descUF  \
# 282        282     False               Bahia
# 1034      1034      True      Rio de Janeiro
# 829        829      True           São Paulo
# 483        483     False  Mato Grosso do Sul
# 167        167      True            Rondônia
# ...        ...       ...                 ...
# 980        980      True        Minas Gerais
# 919        919     False           São Paulo
# 576        576     False           São Paulo
# 53          53      True           São Paulo
# 383        383      True               Bahia
#
#                                               txtRecado  \
# 282                                                 NaN
# 1034                                                NaN
# 829   Obrigado por contribuírem com uma "fatia de pi...
# 483                                   Borda com cerveja
# 167                                                 NaN
# ...                                                 ...
# 980               CÊS SÃO F*DA! BRIGADA POR TUDO SEMPRE
# 919                                                 NaN
# 576                                        Manda pizza!
# 53                                    Sem cebola rsrsrs
# 383                            Assa essa aí com carinho
#
#                           dtPedido
# 282   2023-05-19T20:05:18.000+0000
# 1034  2023-05-24T21:36:24.000+0000
# 829   2023-05-24T16:14:44.000+0000
# 483   2023-05-23T20:32:08.000+0000
# 167   2023-05-15T21:09:09.000+0000
# ...                            ...
# 980   2023-05-24T19:57:25.000+0000
# 919   2023-05-24T18:42:14.000+0000
# 576   2023-05-24T13:40:43.000+0000
# 53    2023-05-12T19:53:51.000+0000
# 383   2023-05-23T10:13:52.000+0000
#
# [100 rows x 5 columns]

# %%
# Pegando o elemento na primeira posição do dataframe
df_sample.iloc[0]
# Out:
# idPedido                              282
# flKetchup                           False
# descUF                              Bahia
# txtRecado                             NaN
# dtPedido     2023-05-19T20:05:18.000+0000
# Name: 282, dtype: object

# %%
# Pegando os 5 primeiros elementos com base no intervalo de 0:4
df_sample.iloc[0:4]
# Out:
#       idPedido flKetchup              descUF  \
# 282        282     False               Bahia
# 1034      1034      True      Rio de Janeiro
# 829        829      True           São Paulo
# 483        483     False  Mato Grosso do Sul
#
#                                               txtRecado  \
# 282                                                 NaN
# 1034                                                NaN
# 829   Obrigado por contribuírem com uma "fatia de pi...
# 483                                   Borda com cerveja
#
#                           dtPedido
# 282   2023-05-19T20:05:18.000+0000
# 1034  2023-05-24T21:36:24.000+0000
# 829   2023-05-24T16:14:44.000+0000
# 483   2023-05-23T20:32:08.000+0000

# %%
# Pegando os  elementos com base em uma lista de posição
df_sample.iloc[[0, 2, 12]]
# Out:
#      idPedido flKetchup        descUF  \
# 282       282     False         Bahia
# 829       829      True     São Paulo
# 523       523      True  Minas Gerais
#
#                                              txtRecado  \
# 282                                                NaN
# 829  Obrigado por contribuírem com uma "fatia de pi...
# 523                                                NaN
#
#                          dtPedido
# 282  2023-05-19T20:05:18.000+0000
# 829  2023-05-24T16:14:44.000+0000
# 523  2023-05-24T12:50:06.000+0000

# %%
# Pegando o elemento com base em seu indice
df_sample.loc[829]
# Out:
# idPedido                                                   829
# flKetchup                                                 True
# descUF                                               São Paulo
# txtRecado    Obrigado por contribuírem com uma "fatia de pi...
# dtPedido                          2023-05-24T16:14:44.000+0000
# Name: 829, dtype: object
